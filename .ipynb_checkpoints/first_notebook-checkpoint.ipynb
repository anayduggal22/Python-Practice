# %%
print("Jupyter is working!")
# Out:
# Jupyter is working!

# %%
name = "Anay"
age = 18
print(f"Name: {name}, Age: {age}")
# Out:
# Name: Anay, Age: 18

# %% [markdown]
# # My First Notebook
# This is a markdown cell. It renders as formatted text.

# %%
# Simple Math
result = 100/4
print(f"Result: {result}")
# Out:
# Result: 25.0
