# %%
import pandas as pd

# --- Creating a DataFrame ---
data = {
    "state": ["Punjab", "Maharashtra", "UP", "MP", "Rajasthan", "Karnataka"],
    "crop": ["Wheat", "Sugarcane", "Rice", "Soybean", "Bajra", "Ragi"],
    "yield_kg": [4800, 8200, 3100, 1200, 900, 800],
    "year": [2023, 2023, 2023, 2023, 2023, 2023],
    "area_hectares": [3200, 1800, 4100, 2900, 1500, 600]
}

df = pd.DataFrame(data)

# --- Basic exploration ---
print(df)
print("\n--- Head ---")
print(df.head(3))

print("\n--- Info ---")
print(df.info())

print("\n--- Describe ---")
print(df.describe())

print("\n--- Shape ---")
print(df.shape)

print("\n--- Columns ---")
print(df.columns)
# Out:
#          state       crop  yield_kg  year  area_hectares
# 0       Punjab      Wheat      4800  2023           3200
# 1  Maharashtra  Sugarcane      8200  2023           1800
# 2           UP       Rice      3100  2023           4100
# 3           MP    Soybean      1200  2023           2900
# 4    Rajasthan      Bajra       900  2023           1500
# 5    Karnataka       Ragi       800  2023            600
#
# --- Head ---
#          state       crop  yield_kg  year  area_hectares
# 0       Punjab      Wheat      4800  2023           3200
# 1  Maharashtra  Sugarcane      8200  2023           1800
# 2           UP       Rice      3100  2023           4100
#
# --- Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          6 non-null      str
#  1   crop           6 non-null      str
#  2   yield_kg       6 non-null      int64
# ...
